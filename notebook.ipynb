# %%
#

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
df = pd.read_pickle('./TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02_mood_labeled.pkl')

# %%
df
# Out:
#                 POET_NAME poem_no  batch_no  POET_RANK   meter  \
# 0              امرء القيس    4730         0          1  taweel
# 1              امرء القيس    4730         1          1  taweel
# 2              امرء القيس    4730         2          1  taweel
# 3              امرء القيس    4730         3          1  taweel
# 4              امرء القيس    4730         4          1  taweel
# ...                   ...     ...       ...        ...     ...
# 23974  خليل ناصيف اليازجي   28987         3        100   kamel
# 23975  خليل ناصيف اليازجي   28987         4        100   kamel
# 23976  خليل ناصيف اليازجي   28989         0        100  baseet
# 23977  خليل ناصيف اليازجي   28989         1        100  baseet
# 23978  خليل ناصيف اليازجي   28989         2        100  baseet
#
#                                                     DATA  BATCH_SIZE  \
# 0      [{'verse_id': '4730_000', 'sadr': 'قفا نبك من ...          12
# ...
