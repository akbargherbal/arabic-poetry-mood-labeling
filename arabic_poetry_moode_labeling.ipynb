# %% [markdown]
# # Arabic Poetry Mood Labeling

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
df = pd.read_pickle('./TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23979 entries, 0 to 23978
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   POET_NAME   23979 non-null  object
#  1   poem_no     23979 non-null  object
#  2   batch_no    23979 non-null  int64
#  3   POET_RANK   23979 non-null  int64
#  4   meter       23979 non-null  object
#  5   DATA        23979 non-null  object
#  6   BATCH_SIZE  23979 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.3+ MB

# %%
df.sample()
# Out:
#               POET_NAME poem_no  batch_no  POET_RANK  meter  \
# 13005  ابن دراج القسطلي   58497         1         45  wafer
#
#                                                     DATA  BATCH_SIZE
# 13005  [{'verse_id': '58497_012', 'sadr': 'نقائذ فتنة...          12

# %%
df.describe()
# Out:
#            batch_no     POET_RANK    BATCH_SIZE
# count  23979.000000  23979.000000  23979.000000
# mean       1.970349     44.768714     10.245006
# std        3.626990     29.061066      3.319789
# min        0.000000      1.000000      1.000000
# 25%        0.000000     17.000000     11.000000
# 50%        1.000000     41.000000     12.000000
# 75%        2.000000     70.000000     12.000000
# max       63.000000    100.000000     12.000000

# %%
from getpass import getpass

token = getpass("GitHub Personal Access Token: ")

# %%
import subprocess

USERNAME = "your_github_username"
REPO = "your_repo"

subprocess.run([
    "git", "config", "--global", "user.name", "Your Name"
], check=True)

subprocess.run([
    "git", "config", "--global", "user.email", "your@email.com"
], check=True)

subprocess.run([
    "git", "remote", "set-url", "origin",
    f"https://{USERNAME}:{token}@github.com/{USERNAME}/{REPO}.git"
], check=True)

# %%
# !python label_moods.py TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02.pkl --device cuda --batch-size 128
