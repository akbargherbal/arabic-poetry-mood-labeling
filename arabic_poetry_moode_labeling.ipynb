# %% [markdown]
# # Arabic Poetry Mood Labeling

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
# !git clone https://github.com/akbargherbal/arabic-poetry-mood-labeling.git
# Out:
# Cloning into 'arabic-poetry-mood-labeling'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 134 (delta 3), reused 9 (delta 2), pack-reused 123 (from 1)
# Receiving objects: 100% (134/134), 128.29 MiB | 13.72 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Updating files: 100% (59/59), done.

# %%
# %cd arabic-poetry-mood-labeling
# Out:
# /content/arabic-poetry-mood-labeling

# %%
df = pd.read_pickle('./TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21868 entries, 0 to 21867
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   POET_NAME   21868 non-null  object
#  1   poem_no     21868 non-null  object
#  2   batch_no    21868 non-null  int64
#  3   POET_RANK   21868 non-null  int64
#  4   meter       21868 non-null  object
#  5   DATA        21868 non-null  object
#  6   BATCH_SIZE  21868 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.2+ MB

# %%
df.sample()
# Out:
#       POET_NAME poem_no  batch_no  POET_RANK   meter  \
# 12800  كثير عزه   22002         2         52  taweel
#
#                                                     DATA  BATCH_SIZE
# 12800  [{'verse_id': '22002_024', 'sadr': 'بما قد أرى...           6

# %%
df.describe()
# Out:
#            batch_no     POET_RANK    BATCH_SIZE
# count  23979.000000  23979.000000  23979.000000
# mean       1.970349     44.768714     10.245006
# std        3.626990     29.061066      3.319789
# min        0.000000      1.000000      1.000000
# 25%        0.000000     17.000000     11.000000
# 50%        1.000000     41.000000     12.000000
# 75%        2.000000     70.000000     12.000000
# max       63.000000    100.000000     12.000000

# %%
from getpass import getpass

# token = getpass("GitHub Personal Access Token: ")

# %%
# import subprocess

# USERNAME = "akbargherbal"
# REPO = "arabic-poetry-mood-labeling"

# subprocess.run([
#     "git", "config", "--global", "user.name", "Your Name"
# ], check=True)

# subprocess.run([
#     "git", "config", "--global", "user.email", "your@email.com"
# ], check=True)

# subprocess.run([
#     "git", "remote", "set-url", "origin",
#     f"https://{USERNAME}:{token}@github.com/{USERNAME}/{REPO}.git"
# ], check=True)

# %%
# !ls
# Out:
# arabic_poetry_moode_labeling.ipynb
# checkpoints
# checkpoint_utils.py
# label_moods.py
# merge_small_batches.py
# notebook.ipynb
# __pycache__
# README.md
# TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A.pkl
# TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02_mood_labeled.pkl
# TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02.pkl

# %%
# !rm -rf checkpoints/

# %%
# Example 1: Run with checkpointing and auto-git-push every 4 chunks (each chunk is 500 rows)
# !python label_moods.py TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A.pkl --device cuda --batch-size 128 --chunk-size 500 --push-every 4

# Example 2: Run with local checkpoints only (disable automatic git pushing)
# !python label_moods.py TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02.pkl --device cuda --batch-size 128 --chunk-size 500 --no-git-push
# Out:
# [1/5] Loading dataframe from TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A.pkl ...
#       21868 rows loaded.
# [2/5] Building batch texts ...
# [3/5] Loading embedding model (BAAI/bge-m3) ...
#       Using device: cuda
# ...
# Loading weights: 100% 391/391 [00:00<00:00, 17470.50it/s]
# [4/5] Encoding batch texts (chunk-size=500, checkpoint-dir=checkpoints, git-push=every 4 chunks) ...
#       chunk 1/44 (rows 0-500) encoded & checkpointed. [500/21868 rows, 20s elapsed]
#       chunk 2/44 (rows 500-1000) encoded & checkpointed. [1000/21868 rows, 41s elapsed]
#       chunk 3/44 (rows 1000-1500) encoded & checkpointed. [1500/21868 rows, 63s elapsed]
#       chunk 4/44 (rows 1500-2000) encoded & checkpointed. [2000/21868 rows, 84s elapsed]
#   [git] pushed -> checkpoint: embeddings through chunk 3 (rows 0-2000/21868)
#       chunk 5/44 (rows 2000-2500) encoded & checkpointed. [2500/21868 rows, 110s elapsed]
# ...

# %%
#

# %%
pwd
# Out:
# '/content/arabic-poetry-mood-labeling'

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
df = pd.read_pickle('./TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A_mood_labeled.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21868 entries, 0 to 21867
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   POET_NAME                 21868 non-null  object
#  1   poem_no                   21868 non-null  object
#  2   batch_no                  21868 non-null  int64
#  3   POET_RANK                 21868 non-null  int64
#  4   meter                     21868 non-null  object
#  5   DATA                      21868 non-null  object
#  6   BATCH_SIZE                21868 non-null  int64
#  7   mood_tags                 21868 non-null  object
#  8   mood_scores               21868 non-null  object
#  9   mood_scores_z             21868 non-null  object
#  10  mood_confidence           21868 non-null  float64
#  11  mood_top2_gap             21868 non-null  float64
#  12  mood_low_confidence       21868 non-null  bool
# ...

# %%
df.to_pickle('./TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02_mood_labeled.pkl', protocol=4)

# %%
df.to_pickle('./TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A_mood_labeled.pkl', protocol=4)

# %%
pwd
# Out:
# '/content/arabic-poetry-mood-labeling'

# %%
# !git add -A

# %%
# !git commit -m "Output saved in protocol 4"
# Out:
# [main 101fe9e] Output saved in protocol 4
#  2 files changed, 0 insertions(+), 0 deletions(-)

# %%
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 7.57 MiB | 1.67 MiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File TOP_100_ARABIC_POETS_OF_ALL_TIME_STAGE_02A_mood_labeled.pkl is 56.12 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/akbargherbal/arabic-poetry-mood-labeling.git
#    97b83c1..101fe9e  main -> main

# %%
#
